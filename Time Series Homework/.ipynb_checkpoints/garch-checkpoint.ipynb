# %%
import numpy as np
import pandas as pd
import arch as arch
from pathlib import Path
# %matplotlib inline

# %%
csvpath = Path('../Resources/GSPC.csv')
sp500 = pd.read_csv(csvpath, parse_dates=True, index_col='Date')
sp500.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1997-01-02  740.739990  742.809998  729.549988  737.010010  737.010010
# 1997-01-03  737.010010  748.239990  737.010010  748.030029  748.030029
# 1997-01-06  748.030029  753.309998  743.820007  747.650024  747.650024
# 1997-01-07  747.650024  753.260010  742.179993  753.229980  753.229980
# 1997-01-08  753.229980  755.719971  747.710022  748.409973  748.409973
#
#                Volume
# Date
# 1997-01-02  463230000
# 1997-01-03  452970000
# 1997-01-06  531350000
# 1997-01-07  538220000
# 1997-01-08  557510000

# %%
sp500.Close.plot()

# %%
# September 11th attack, bursting of dot-com bubble
sp500.loc['2000':'2002'].Close.plot()

# %%
sp500.loc['2008':'2009'].Close.plot()

# %% [markdown]
# Stationarity needed for ARMA and GARCH
#
# Doesn't matter for ARIMA

# %%
# GARCH assumes stationarity
# Clustering of volatility seen, e.g. 2008-2010
sp500['Close'].pct_change().plot()

# %%
# Focus on the 2008-2009 Financial Crisis Period
returns = sp500.loc['2008':'2009'].Close.pct_change()# * 100
returns
returns = returns.dropna()
returns.tail()
# Out:
# Date
# 2009-12-24    0.005256
# 2009-12-28    0.001154
# 2009-12-29   -0.001401
# 2009-12-30    0.000195
# 2009-12-31   -0.010050
# Name: Close, dtype: float64

# %% [markdown]
# # GARCH

# %%
from arch import arch_model

# %%
# 'p' and 'q'  are akin to the 'p' and 'q' of an ARMA model.
# 'vol="GARCH"' means that we're using a GARCH model.
# The 'mean="Zero"' means that we're estimating a GARCH.
model = arch_model(returns, mean="Zero", vol="GARCH", p=1, q=1)

# %%
# Fit the GARCH Model
res = model.fit(disp="off")
# Out:
# /Users/samueldolgin/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/arch/univariate/base.py:317: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004815. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   data_scale_warning.format(orig_scale, rescale), DataScaleWarning

# %%
# Summarize the model results
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  Close   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.002
# Vol Model:                      GARCH   Log-Likelihood:                1326.90
# Distribution:                  Normal   AIC:                          -2647.79
# Method:            Maximum Likelihood   BIC:                          -2635.12
#                                         No. Observations:                  504
# Date:                Thu, Apr 15 2021   Df Residuals:                      504
# Time:                        20:07:56   Df Model:                            0
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      9.4645e-06  1.228e-11  7.709e+05      0.000 [9.465e-06,9.465e-06]
# alpha[1]       0.1035  1.784e-02      5.799  6.677e-09   [6.850e-02,  0.138]
# beta[1]        0.8700  1.286e-02     67.626      0.000     [  0.845,  0.895]
# ============================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# # Forecasting from GARCH

# %%
# Construct Volatility Forecasts for the next 3 days
forecast_horizon = 3
# Take the last day of the data we used above. 
# If forecast horizon is 3, then the resulting 'h.1', 'h.2', and 'h.3' 
# are the forecasts for the following 3 days.
forecasts = res.forecast(start='2009-12-31', horizon=forecast_horizon)
forecasts
# Out:
# /Users/samueldolgin/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/arch/__future__/_utility.py:21: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   FutureWarning,

# %%
np.sqrt(forecasts.variance.dropna() * 252)
# Out:
#                  h.1       h.2       h.3
# Date
# 2009-12-31  0.162545  0.167644  0.172463

# %% [markdown]
# 3 trading days after 12/31/2009

# %%
# Annualize the forecast
intermediate = np.sqrt(forecasts.variance.dropna() * 252)
intermediate
# Out:
#                  h.1       h.2       h.3
# Date
# 2009-12-31  0.162545  0.167644  0.172463

# %% [markdown]
# # Visualizing the forecast

# %%
# The name of the column here is the date of the forecast.
# Each row represents the forecast of volatility for the following days.
# Transposing makes the forecast easier to plot
final = intermediate.dropna().T
final
# Out:
# Date  2009-12-31
# h.1    13.007879
# h.2    13.223021
# h.3    13.433750

# %%
final.plot()
